# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

df = pd.read_csv('Student_Performance.csv',sep=',')
#df['Date'] = pd.to_datetime(df['Date'],format='%d/%m/%Y')

# %%
display(df.head(5))
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB
# None
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# ...

# %%
#TOAMR CUIDADO QUE TEM MUITA COLINEARIDADE NESSA BASE DE DADOS

for i in range(len(df.columns)-2):
    plt.figure()
    plt.plot(df.iloc[:,i],df.iloc[:,-1],'o')
    plt.show()

# %%
df_bike_mes = df[['Date','Rented Bike Count']].copy()

df_bike_mes['Month'] = df_bike_mes['Date'].dt.month
df_bike_mes['Month Name'] = df_bike_mes['Date'].dt.month_name()
df_bike_mes['Month Name'] = df_bike_mes['Month Name'].str.slice(stop=3)

df_bike_mes = df_bike_mes[['Rented Bike Count','Month','Month Name']].groupby(['Month','Month Name'],as_index=False).sum()

plt.figure()
plt.grid(alpha=0.3)
plt.bar(x=df_bike_mes['Month Name'],height= df_bike_mes['Rented Bike Count']/1000 ,color='red',edgecolor='black',label='12/2017-12/2018')
#plt.xticks(rotation=45,horizontalalignment='right')
plt.xlabel('Meses')
plt.ylabel('Bikes alugadas (milhares)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_bike_mes = df[['Date','Rented Bike Count']].copy()
#       3 df_bike_mes['Month'] = df_bike_mes['Date'].dt.month
#       4 df_bike_mes['Month Name'] = df_bike_mes['Date'].dt.month_name()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...
